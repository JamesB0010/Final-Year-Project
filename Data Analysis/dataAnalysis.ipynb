# %%
#Import necessary libraries and load excel file
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap
from IPython.display import display
import ipywidgets as widgets
import os

excelFile = 'Reel Together Evaluation Form.xlsx'
xls = pd.ExcelFile(excelFile)

# %%
# Define the click handler
def exportButtonClicked(arg):
    print("Exporting images...")

    output_dir = "exported_charts"
    os.makedirs(output_dir, exist_ok=True)

    for fig, name in figures:
        filename = os.path.join(output_dir, f"{name}_likert.png")
        fig.savefig(filename, dpi=300, bbox_inches='tight')
        plt.close(fig)  # Free memory
        print(f"Saved: {filename}")

    print("All images exported.")

buttonSaveImages = widgets.Button(description = "Save images")
buttonSaveImages.on_click(exportButtonClicked)

# %%
def IsValidSheet(name):
    return name.startswith("GUESS") and not name.endswith("Feedback")

# %%
#Filter worksheet names
validSheets = [name for name in xls.sheet_names if IsValidSheet(name)]
validSheets.insert(0,"SUS")

# %%
figures = []  # List to store the figures

for i, sheetName in enumerate(validSheets):
    print(f"Processing sheet: {sheetName}")

    # Read sheet (no skipped rows)
    df = pd.read_excel(excelFile, sheet_name=sheetName)

    # Extract question titles and numeric data
    question_titles = df.columns[1:]
    dfNumeric = df.iloc[:, 1:]

    # Determine Likert scale range
    maxScale = 5 if i == 0 else 7
    scaleRange = list(range(1, maxScale + 1))

    # Calculate normalized response frequencies
    likert_summary = dfNumeric.apply(lambda x: x.value_counts(normalize=True)).fillna(0).T
    for val in scaleRange:
        if val not in likert_summary.columns:
            likert_summary[val] = 0
    likert_summary = likert_summary[scaleRange] * 100  # Convert to percent

    # Wrap long question titles
    wrapped_titles = [textwrap.fill(title, width=40) for title in question_titles]
    likert_summary.index = wrapped_titles

    # Set response labels
    response_labels = [
        "Strongly Disagree", "Disagree", "Neither Agree nor Disagree", "Agree", "Strongly Agree"
    ] if maxScale == 5 else [
        "Strongly Disagree", "Disagree", "Somewhat Disagree",
        "Neither Agree nor Disagree", "Somewhat Agree", "Agree", "Strongly Agree"
    ]

    # Set figure height dynamically
    num_questions = len(wrapped_titles)
    fig_height = max(6, num_questions * 0.6)

    # Create figure and axes
    fig, ax = plt.subplots(figsize=(16, fig_height))

    # Plot into the axes
    likert_summary.plot(
        kind='barh',
        stacked=True,
        colormap='coolwarm_r',
        ax=ax
    )

    ax.set_title(f"Likert Responses - {sheetName}")
    ax.set_xlabel("Percentage of Responses")
    ax.set_ylabel("Questions")
    ax.legend(response_labels, title="Response", bbox_to_anchor=(1.05, 1), loc='upper left')

        # --- Additional Statistics Output ---
    stats_df = pd.DataFrame(index=question_titles)

    # Count of responses per value
    for val in scaleRange:
        stats_df[f'Count_{val}'] = dfNumeric.apply(lambda col: (col == val).sum())

    # Mean and standard deviation
    stats_df['Mean'] = dfNumeric.mean(axis=0)
    stats_df['StdDev'] = dfNumeric.std(axis=0)

    # Wrap titles for display
    stats_df.index = wrapped_titles

    print(f"\nStatistics for {sheetName}:\n")
    display(stats_df.round(2))


    plt.tight_layout()

    # Store the figure
    figures.append((fig, sheetName))
# Out:
# Processing sheet: SUS
#
# Statistics for SUS:
#                                                     Count_1  Count_2  Count_3  \
# I Think that i would like to use this\nsystem f...        2        2        1
# I found the system unnecessarily complex                  2       12        4
# I thought the system was easy to use                      1        7        2
# I think that i would need the support of\na tec...        3        6        1
# I found the system very cumbersome to\nuse                2        9        4
# I thought there was too much\ninconsistency in ...        0        3        4
# I would imagine that most people would\nlearn t...        1        1        1
# I found the system very cumbersome to\nuse.               3        6        6
# I felt very confident using the system.                   1        0        1
# I needed to learn a lot of things before\nI cou...        5        4        4
#
# ...

# %%
display(buttonSaveImages)
# Out:
# Button(description='Save images', style=ButtonStyle())
